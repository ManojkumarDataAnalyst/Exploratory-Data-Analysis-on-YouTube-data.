# %% [markdown]
# # Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
#Import required libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.float_format',lambda x :'%0.5f'%x)

# %%
#read the provided dataset (youtube_dislike_dataset.csv)
df_yt = pd.read_csv('youtube_dislike_dataset.csv')
df_yt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
#retrieve top 5 records
df_yt.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#retrieve  bottom 5 records
df_yt.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ##  Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df_yt.shape,df_yt.dtypes

#Inference_shape : In this dataset there are 12 columns and 37422 rows.
#Inference_dtypes : In this dataset there are only three integer64 dtypes variables (view_count,likes,dislikes,comment_count) which 
#are numerical values and other remaining variables are categorical values.
# Out:
# ((37422, 12),
#  video_id         object
#  title            object
#  channel_id       object
#  channel_title    object
#  published_at     object
#  view_count        int64
#  likes             int64
#  dislikes          int64
#  comment_count     int64
#  tags             object
#  description      object
#  comments         object
#  dtype: object)

# %% [markdown]
# ##  Check for the Percentage of the missing values and drop or impute them.

# %%
#The Percentage of the missing values and drop or impute them.

percentage_missingvalues = (df_yt.isna().sum()/df_yt.count())*100,df_yt.isna().sum()
percentage_missingvalues

#In this dataset the miising values are only in the comments varialble and the missing percentage of the variable are 
#very low(0.424%)so that we can drop them.
# Out:
# (video_id        0.00000
#  title           0.00000
#  channel_id      0.00000
#  channel_title   0.00000
#  published_at    0.00000
#  view_count      0.00000
#  likes           0.00000
#  dislikes        0.00000
#  comment_count   0.00000
#  tags            0.00000
#  description     0.00000
#  comments        0.42400
#  dtype: float64,
#  video_id           0
#  title              0
#  channel_id         0
#  channel_title      0
#  published_at       0
#  view_count         0
#  likes              0
#  dislikes           0
#  comment_count      0
#  tags               0
#  description        0
#  comments         158
#  dtype: int64)

# %%
#The missing values are droped in this dataset
df_yt.dropna(inplace= True)
df_yt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# ## Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
#The statistical summary of  numerical.
df_yt.describe()

#The numerical values in this dataset has wide range of data distribution because of higher standard deivation
# Out:
#             view_count          likes      dislikes  comment_count
# count      37264.00000    37264.00000   37264.00000    37264.00000
# mean     5710821.45003   167286.69700    4996.43412     9966.95315
# std     24313037.50711   538493.10269   30751.93784   117346.46657
# min        20368.00000       22.00000       3.00000        1.00000
# 25%       514130.50000    13317.25000     282.75000      914.00000
# 50%      1321860.50000    42556.00000     798.00000     2347.00000
# 75%      3674527.25000   130966.50000    2466.25000     6212.00000
# max   1322796924.00000 31837675.00000 2397733.00000 16071029.00000

# %%
#The statistical summary of  categorical columns.
df_yt.describe(include='object')
#There are 10891 unique channel are present in this dataset.
#Among 37264 only 10813 unique channel names are aviable in this dataset.
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# ## Convert datatype of column published_at from object to pandas datetime.

# %%
#Convert datatype of column published_at from object to pandas datetime.
df_yt['published_at'] = pd.to_datetime(df_yt['published_at'])
df_yt.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# ## Create a new column as 'published_month' using the column published_at (display the months only)

# %%
#Create a new column as 'published_month' using the column published_at (display the months only)
df_yt['published_month'] = df_yt['published_at'].dt.month
df_yt['published_month']
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37264, dtype: int64

# %%
df_yt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ## Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.

# %%
df_yt['published_month'] = df_yt['published_at'].dt.strftime('%B')

# %%
df_yt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
df_yt.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments', 'published_month'],
#       dtype='object')

# %%
df_yt.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments', 'published_month'],
#       dtype='object')

# %% [markdown]
# ## Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
#grouping by months


video_month = df_yt.groupby(('published_month'))

# %%
#apply aggregate function onto grouped month

video_month['title'].count().sort_values(ascending=False)
# Out:
# published_month
# October      4976
# September    4854
# November     4821
# August       4250
# December     3063
# July         2331
# June         2305
# March        2248
# February     2125
# April        2119
# January      2099
# May          2073
# Name: title, dtype: int64

# %% [markdown]
# ## Find the count of unique video_id, channel_id and channel_title.

# %%
#The count of unique video_id.

len(df_yt['video_id'].unique())
# Out:
# 37264

# %%
#The count of unique channel_id.

len(df_yt['channel_id'].unique())
# Out:
# 10891

# %%
#The count of unique channel_title.
 
len(df_yt['channel_title'].unique())
# Out:
# 10813

# %% [markdown]
# ## Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
# The top 10 channel names having the highest number of videos

df_yt.groupby(by='channel_title')[['video_id']].count().sort_values(by='video_id',ascending=False).head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
# The bottom 10 channel names having the highest number of videos.

df_yt.groupby(by='channel_title')[['video_id']].count().sort_values(by='video_id',ascending=False).tail(10)
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %% [markdown]
# ## Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
df_yt.groupby(by = 'likes')[['title']].max().tail(1)

#Among 36958 unique title BTS () 'Dynamite' Official MV as more number of likes
# Out:
#                                   title
# likes
# 31837675  BTS () 'Dynamite' Official MV

# %%
df_yt.groupby(by ='likes' )[['title']].min().head(1)
#Among 36958 unique title leading th charge has less number of likes.
# Out:
#                                title
# likes
# 22     Leading the Charge | Circle K

# %% [markdown]
# ## Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
df_yt.groupby(by ='dislikes')[['title']].max().tail(1)
#Among 36958 unique title cuties has more number of dilikes.
# Out:
#                                         title
# dislikes
# 2397733   Cuties | Official Trailer | Netflix

# %%
df_yt.groupby(by = 'dislikes')[['title']].min().head(1)
#Among 36958 unique title Tims For Good: A Taste Of The Familiar has less number of dilikes.
# Out:
#                                            title
# dislikes
# 3         Tims For Good: A Taste Of The Familiar

# %% [markdown]
# ## Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
df_yt.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments', 'published_month'],
#       dtype='object')

# %%
#First we can create the correlation relationship with this two variable View count and Dislikes.
cor_twovar = df_yt['view_count'].corr(df_yt['dislikes'])
cor_twovar

#The correlation of this two_var is 0.684575 which is positive
# Out:
# 0.6845758297072598

# %%
df_yt.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments', 'published_month'],
#       dtype='object')

# %%
df_yt.plot.scatter(x='view_count',y='dislikes')
plt.show()
#IF the number of views increases the no.of dislikes also tend to increases.

# %% [markdown]
# ## Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
jan_videos = df_yt[df_yt['published_at'].dt.month==1]
jan_videos
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
jan_videos['published_at'].count()
# Out:
# 2099
